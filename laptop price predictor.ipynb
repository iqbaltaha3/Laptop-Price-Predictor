# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %% [markdown]
# # Initial Preprocessing of Data

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df['Ram']=df['Ram'].astype('int32')

# %%
df['Weight']=df['Weight'].astype('float32')

# %%
df.shape
# Out:
# (1303, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# # Univariate and Bivariate Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
c = ['Company','TypeName','OpSys']
for i in c:
    plt.subplots(figsize=(20,10))
    df[i].value_counts().plot(kind='bar')
    plt.grid()
    plt.xticks(rotation=0)
    plt.title(i)
    plt.show()

# %%
# Suppress specific warnings
import warnings
# Suppress all FutureWarnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
c1 = ['Inches','Ram','Weight','Price']
for i in c1:
    plt.subplots(figsize=(15,10))
    sns.histplot(df[i],kde=True)
    plt.grid()
    plt.show()

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
#        'Memory', 'Gpu', 'OpSys', 'Weight', 'Price'],
#       dtype='object')

# %%
c2 = ['Company','TypeName','Inches','Ram','OpSys']
for i in c2:
    plt.subplots(figsize=(15,10))
    sns.barplot(x=df[i],y=df['Price'])
    plt.grid()
    plt.show()

# %%
c2 = ['Company','TypeName','Inches','Ram','OpSys']
for i in c2:
    plt.subplots(figsize=(15,10))
    sns.boxplot(x=df[i],y=df['Price'])
    plt.grid()
    plt.show()

# %% [markdown]
# # Feature Engineering

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232
# ...

# %%
df['Touchscreen']=df['ScreenResolution'].apply(lambda x: 1 if 'Touchscreen' in x else 0)

# %%
df['Ips']=df['ScreenResolution'].apply(lambda x: 1 if 'IPS' in x else 0)

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches    ScreenResolution  \
# 495   Lenovo  Ultrabook    12.5  IPS Panel 1366x768
# 318       HP   Notebook    14.0   Full HD 1920x1080
# 759     Acer   Notebook    15.6            1366x768
# 119     Asus   Notebook    15.6   Full HD 1920x1080
# 1049    Asus    Netbook    11.6            1366x768
#
#                                        Cpu  Ram              Memory  \
# 495             Intel Core i5 6200U 2.3GHz    8           180GB SSD
# 318             Intel Core i5 7200U 2.5GHz    8           256GB SSD
# 759             Intel Core i5 7200U 2.5GHz    4           256GB SSD
# 119             Intel Core i7 8550U 1.8GHz    8           256GB SSD
# 1049  Intel Celeron Dual Core N3060 1.6GHz    4  16GB Flash Storage
#
#                         Gpu       OpSys  Weight      Price  Touchscreen  Ips
# 495   Intel HD Graphics 520  Windows 10    1.30  58554.720            0    1
# 318   Intel HD Graphics 620  Windows 10    1.95  52214.400            0    0
# ...

# %%
new = df['ScreenResolution'].str.split('x',expand=True)

# %%
df['x_res']=new[0]
df['y_res']=new[1]

# %%
df['x_res'] = df['x_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches  \
# 1242    Acer            Notebook    15.6
# 1169     MSI              Gaming    15.6
# 315     Dell            Notebook    15.6
# 234     Acer  2 in 1 Convertible    13.3
# 980     Dell  2 in 1 Convertible    15.6
#
#                                ScreenResolution                         Cpu  \
# 1242                                   1366x768  Intel Core i3 6006U 2.0GHz
# 1169                IPS Panel Full HD 1920x1080  Intel Core i7 7500U 2.7GHz
# 315                           Full HD 1920x1080  Intel Core i5 8250U 1.6GHz
# 234   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i5 6200U 2.3GHz
# 980   IPS Panel Full HD / Touchscreen 1920x1080  Intel Core i7 7500U 2.7GHz
#
#       Ram                Memory                      Gpu       OpSys  Weight  \
# 1242    4             500GB HDD    Intel HD Graphics 520       Linux    2.40
# 1169    8               1TB HDD  Nvidia GeForce GTX 1050  Windows 10    2.20
# ...

# %%
c2 = ['Touchscreen','Ips','x_res','y_res']
for i in c2:
    plt.subplots(figsize=(15,10))
    sns.barplot(x=df[i],y=df['Price'])
    plt.grid()
    plt.show()

# %%
df['x_res'] = df['x_res'].astype('int32')
df['y_res'] = df['y_res'].astype('int32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  Ips               1303 non-null   int64
#  13  x_res             1303 non-null   int32
#  14  y_res             1303 non-null   int32
# dtypes: float32(1), float64(2), int32(3), int64(2), object(7)
# ...

# %%
numerical_df = df.select_dtypes(include=['number'])

# %%
sns.heatmap(numerical_df.corr())
# Out:
# <Axes: >

# %%
numerical_df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# x_res          0.556529
# y_res          0.552809
# Name: Price, dtype: float64

# %% [markdown]
# Inches has no significant direct relation with price . While x_res and y_res are mutually correlated to each other .
#
# So we will create a new column called 'ppi'(pixels per inch).

# %%
df['ppi'] = (((df['x_res']**2) + (df['y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.sample(5)
# Out:
#      Company  TypeName  Inches             ScreenResolution  \
# 1012      HP  Notebook    14.0            Full HD 1920x1080
# 975       HP  Notebook    15.6  IPS Panel Full HD 1920x1080
# 588   Lenovo  Notebook    15.6         Touchscreen 1366x768
# 446     Acer  Notebook    15.6                     1366x768
# 1292    Dell  Notebook    15.6                     1366x768
#
#                                        Cpu  Ram                Memory  \
# 1012            Intel Core i5 7200U 2.5GHz    4             256GB SSD
# 975            Intel Core i5 7200U 2.70GHz    8  128GB SSD +  1TB HDD
# 588             Intel Core i7 8550U 1.8GHz   12               1TB HDD
# 446             Intel Core i5 7200U 2.5GHz    4             500GB HDD
# 1292  Intel Celeron Dual Core N3050 1.6GHz    2             500GB HDD
#
#                         Gpu       OpSys  Weight      Price  Touchscreen  Ips  \
# 1012  Intel HD Graphics 620  Windows 10    1.48  84715.200            0    0
# ...

# %%
numerical_df = df.select_dtypes(include=['number'])

# %%
numerical_df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# x_res          0.556529
# y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df.drop(columns=['ScreenResolution','x_res','y_res','Inches'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %%
sns.scatterplot(x=df['ppi'],y=df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %%
df['cpu name']=df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       cpu name
# ...

# %%
def cpu(text):
    if text == 'Intel Core i5' or text == 'Intel Core i3' or text == 'Intel Core i7' :
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processors'
        else:
            return 'AMD Processor'

# %%
df['Cpu Brand'] = df['cpu name'].apply(cpu)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       cpu name      Cpu Brand
# ...

# %%
df.drop(columns=['Cpu','cpu name'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook    8            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook    8  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook    8            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook   16            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook    8            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  Ips         ppi      Cpu Brand
# 0  macOS    1.37   71378.6832            0    1  226.983005  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.211998  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534624  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983005  Intel Core i5

# %%
df['Cpu Brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu Brand'>

# %%
sns.barplot(x=df['Cpu Brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.grid()
plt.show()

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
# Clean and split the 'Memory' column
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')

# Split memory into parts
new = df["Memory"].str.split("+", n=1, expand=True)
df["first"] = new[0].str.strip()
df["second"] = new[1].fillna("0").str.strip()

# Extract numeric values from 'first' and 'second' parts
df['first'] = df['first'].str.extract('(\d+)').fillna(0).astype(int)
df['second'] = df['second'].str.extract('(\d+)').fillna(0).astype(int)

# Convert 'second' to string to avoid errors in the lambda function
df['second'] = df['second'].astype(str)

# Extract storage types from 'first' part
df["Layer1HDD"] = df["Memory"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["Memory"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["Memory"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["Memory"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Extract storage types from 'second' part
df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

# Calculate total storage for each type
df["HDD"] = (df["first"] * df["Layer1HDD"] + df["second"].astype(int) * df["Layer2HDD"])
df["SSD"] = (df["first"] * df["Layer1SSD"] + df["second"].astype(int) * df["Layer2SSD"])
df["Hybrid"] = (df["first"] * df["Layer1Hybrid"] + df["second"].astype(int) * df["Layer2Hybrid"])
df["Flash_Storage"] = (df["first"] * df["Layer1Flash_Storage"] + df["second"].astype(int) * df["Layer2Flash_Storage"])

# Drop intermediate columns
df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage',
                  'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'], inplace=True)

df
# Out:
#      Company            TypeName  Ram             Memory  \
# 0      Apple           Ultrabook    8            128 SSD
# 1      Apple           Ultrabook    8  128 Flash Storage
# 2         HP            Notebook    8            256 SSD
# 3      Apple           Ultrabook   16            512 SSD
# 4      Apple           Ultrabook    8            256 SSD
# ...      ...                 ...  ...                ...
# 1298  Lenovo  2 in 1 Convertible    4            128 SSD
# 1299  Lenovo  2 in 1 Convertible   16            512 SSD
# 1300  Lenovo            Notebook    2   64 Flash Storage
# 1301      HP            Notebook    6           1000 HDD
# 1302    Asus            Notebook    4            500 HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# 2            Intel HD Graphics 620       No OS    1.86   30636.0000
# ...

# %%
c3=['Flash_Storage','SSD','HDD','Hybrid']
for i in c3:
    df[i].value_counts().plot(kind='bar')
    plt.title(i)
    plt.show()

# %%
numerical_cols = df.select_dtypes(include='number')

# %%
numerical_cols.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.303621
# SSD              0.676202
# Hybrid          -0.020186
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df['Price']=df['Price'].astype('int')

# %%
df.sample(5)
# Out:
#      Company   TypeName  Ram                    Gpu       OpSys  Weight  \
# 1241    Asus  Ultrabook    8  Intel HD Graphics 520  Windows 10    1.45
# 1296      HP    Netbook    2  Intel HD Graphics 400  Windows 10    1.17
# 1083      HP  Ultrabook   16  Intel HD Graphics 620  Windows 10    1.30
# 859   Lenovo   Notebook    4  Intel HD Graphics 520       No OS    2.20
# 377     Dell   Notebook    4  Intel HD Graphics 400  Windows 10    1.80
#
#        Price  Touchscreen  Ips         ppi               Cpu Brand   HDD  SSD
# 1241   68198            0    0  165.632118           Intel Core i7     0  256
# 1296   11135            0    0  135.094211  Other Intel Processors     0    0
# 1083  109170            0    1  331.264236           Intel Core i7     0  512
# 859    24988            0    0  141.211998           Intel Core i3  1000    0
# 377    16463            0    0  100.454670  Other Intel Processors   500    0

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
df['Gpu Brand']=df['Gpu'].apply(lambda x:x.split()[0])

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu Brand'] != 'ARM']

# %%
df['Gpu Brand'].value_counts()
# Out:
# Gpu Brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %%
df.drop(columns=['Gpu'],inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14512\1111925144.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['Gpu'],inplace=True)

# %%
sns.barplot(x=df['Gpu Brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind='bar')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def ops(text):
    if text == 'Windows 10' or text == 'Windows 7' or text == 'Windows 10 S' :
        return 'Windows'
    elif text == 'macOS' or text == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os']=df['OpSys'].apply(ops)
df.drop(columns=['OpSys'],inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14512\3115012181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['os']=df['OpSys'].apply(ops)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14512\3115012181.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['OpSys'],inplace=True)

# %%
df.sample(10)
# Out:
#       Company   TypeName  Ram  Weight   Price  Touchscreen  Ips         ppi  \
# 151      Dell     Gaming    8    2.62   47898            0    0  141.211998
# 1262     Dell   Notebook    6    2.30   24455            0    0  100.454670
# 1118  Toshiba  Ultrabook   16    1.05  118601            0    0  165.632118
# 150      Dell     Gaming   16    2.56   66560            0    0  141.211998
# 587    Lenovo  Ultrabook   12    1.40   89137            0    1  157.350512
# 540      Dell  Ultrabook    8    1.20   74538            1    0  276.053530
# 188      Acer  Ultrabook    8    1.12   52693            0    1  165.632118
# 769      Acer   Notebook    4    2.10   15877            0    0  100.454670
# 879        HP   Notebook    4    2.04   44701            0    0  141.211998
# 213    Lenovo   Notebook    8    2.20   29250            0    0  141.211998
#
#                    Cpu Brand   HDD  SSD Gpu Brand                  os
# ...

# %%
sns.barplot(x=df['os'],y=df['Price'])
# Out:
# <Axes: xlabel='os', ylabel='Price'>

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14512\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
sns.histplot(df['Price'],kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# As we could see the target column is Right Skewed so we need to normalize it then we could use it in the linear model.

# %%
sns.histplot(np.log(df['Price']),kde=True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %% [markdown]
# # Model Training

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175745
# 1       10.776766
# 2       10.329931
# 3       11.814473
# 4       11.473093
#           ...
# 1298    10.433880
# 1299    11.288106
# 1300     9.409273
# 1301    10.614106
# 1302     9.886341
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=42)

# %%
X_train
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 945   Lenovo              Gaming   16    2.50            0    1  141.211998
# 428       HP              Gaming   12    3.35            0    0  127.335675
# 1261    Asus           Ultrabook    8    1.20            0    1  165.632118
# 174       HP            Notebook    8    2.50            0    0  127.335675
# 398     Dell         Workstation    8    1.78            1    0  282.423996
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1095    Acer            Notebook    8    2.40            0    0  141.211998
# 1130      HP            Notebook    8    2.04            0    0  100.454670
# 1295    Dell            Notebook    8    2.30            0    0  100.454670
# 860   Lenovo            Notebook    8    2.30            0    1  141.211998
# 1126  Lenovo  2 in 1 Convertible    4    0.69            1    1  224.173809
#
# ...

# %%
X_test
# Out:
#       Company   TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 478      Dell   Notebook    8    2.20            0    0  141.211998
# 724       MSI     Gaming    8    2.70            0    0  127.335675
# 312       MSI     Gaming   16    2.80            0    1  141.211998
# 851      Asus     Gaming   16    2.10            0    0  141.211998
# 1276     Dell   Notebook    6    2.30            0    0  100.454670
# ...       ...        ...  ...     ...          ...  ...         ...
# 506      Asus   Notebook    8    2.00            0    0  141.211998
# 168      Acer   Notebook    8    3.00            0    1  127.335675
# 1170       HP   Notebook    8    1.96            0    0  141.211998
# 862   Toshiba   Notebook    4    1.05            0    0  165.632118
# 208      Dell  Ultrabook    8    1.20            0    0  165.632118
#
#           Cpu Brand   HDD  SSD Gpu Brand       os
# 478   Intel Core i5  1000    0       AMD  Windows
# ...

# %%
y_train
# Out:
# 945     10.882302
# 428     11.575957
# 1261    10.567232
# 174     10.803181
# 398     11.881000
#           ...
# 1095    10.658905
# 1130    10.419689
# 1295    10.667629
# 860     10.721570
# 1126    10.147257
# Name: Price, Length: 1106, dtype: float64

# %%
y_test
# Out:
# 478     10.490274
# 724     11.182294
# 312     11.624771
# 851     11.524637
# 1276    10.104590
#           ...
# 506     11.085429
# 168     10.725490
# 1170    10.496179
# 862     11.134063
# 208     11.254181
# Name: Price, Length: 196, dtype: float64

# %% [markdown]
# Import All Libraries and modules required for model training.
#
# **Also importing several ML Algorithms to compare their performance on the same data.**

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score , mean_absolute_error

from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from xgboost import XGBRegressor

# %% [markdown]
# ### Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('r2_score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# r2_score 0.7930680877425931
# MAE 0.2133498208820592

# %% [markdown]
# ### Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7841245560682356
# MAE 0.21970787064979344

# %% [markdown]
# ### Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7877175175246551
# MAE 0.21788948815505513

# %% [markdown]
# ### KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=6)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7564951635451596
# MAE 0.22578211777910295

# %% [markdown]
# ### Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=9)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.82464844649251
# MAE 0.19140176352705787

# %% [markdown]
# ### SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8181496929817317
# MAE 0.1896213689887227

# %% [markdown]
# ### Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.8,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8516122466075847
# MAE 0.17319843241369798

# %% [markdown]
# ### ExtraTrees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=None,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8666527953689784
# MAE 0.164762729184482

# %% [markdown]
# ### AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7529922383668514
# MAE 0.24796962777752302

# %% [markdown]
# ### Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=400)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.859325955980938
# MAE 0.17071576679547967

# %% [markdown]
# ### XGBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=100,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8826632551406915
# MAE 0.1502046502397839

# %% [markdown]
# ### Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=None,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8603527271693734
# MAE 0.17081150708803175

# %% [markdown]
# ### Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.851234824061089
# MAE 0.18058004230306882

# %% [markdown]
# # Exporting the model

# %%
import pickle

# %%
#pickle.dump(df,open('df.pkl','wb'))
#pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight   Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378            0    1
# 1      Apple           Ultrabook    8    1.34   47895            0    0
# 2         HP            Notebook    8    1.86   30636            0    0
# 3      Apple           Ultrabook   16    1.83  135195            0    1
# 4      Apple           Ultrabook    8    1.37   96095            0    1
# ...      ...                 ...  ...     ...     ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866            1    1
# 1300  Lenovo            Notebook    2    1.50   12201            0    0
# 1301      HP            Notebook    6    2.19   40705            0    0
# 1302    Asus            Notebook    4    2.20   19660            0    0
#
#              ppi               Cpu Brand   HDD  SSD Gpu Brand  \
# ...
